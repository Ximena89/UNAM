# %%
# Reading the five catalogs for different color-to-mass ratios.

# catalog_T =  Read('SDSS_DR7_sersic_photometric_catalog_Taylor_gi.txt')
# catalog_Bgr =  Read('SDSS_DR7_sersic_photometric_catalog_Bell_gr.txt')
# catalog_Bgi =  Read('SDSS_DR7_sersic_photometric_catalog_Bell_gi.txt')
# catalog_Zgr =  Read('SDSS_DR7_sersic_photometric_catalog_Zibetti_gr.txt')
# catalog_Zgi =  Read('SDSS_DR7_sersic_photometric_catalog_Zibetti_gi.txt')



# 3D
Ms_gi_3d = catalog_T['Ms3D_at_Re']
Re_ste_gi_3d = catalog_T['re3D']
Ms_gr_3d = catalog_Zgr['Ms3D_at_Re']
Re_ste_gr_3d = catalog_Zgr['re3D']


####### All the missing variables are in catalog.ipynb or can be extracted from the catalogs above.

# 3D ratios in the r band

ratio_gi_3d = Re_ste_gi_3d/Re_r_gi
ratio_gr_3d = Re_ste_gr_3d/Re_r_grZ

# 3D early masses 

Ms_gi_early_3d = Ms_gi_3d[sphr_gi]
Ms_gr_early_3d = Ms_gr_3d[sphr_grZ]

# 3D late masses  

Ms_gi_late_3d = Ms_gi_3d[disk_gi]
Ms_gr_late_3d = Ms_gr_3d[disk_grZ]

# 3D early radii  

re_gi_early_3d = Re_ste_gi_3d[sphr_gi]
re_gr_early_3d = Re_ste_gr_3d[sphr_grZ]

# 3D late radii 

re_gi_late_3d = Re_ste_gi_3d[disk_gi]
re_gr_late_3d = Re_ste_gr_3d[disk_grZ]

# Early 3D ratios in the r band 

r_gi_early_3d = ratio_gi_3d[sphr_gi]
r_gr_early_3d = ratio_gr_3d[sphr_grZ]

# Late 3D ratios in the r band 

r_gi_late_3d = ratio_gi_3d[disk_gi]
r_gr_late_3d = ratio_gr_3d[disk_grZ]




# # Average stellar mass 3D. Ratio effective radii. 20 bins Late galaxies

# stat_gi_late_3d_mean, gilate_3d_means_bins, binnum_3d_gilate_mean = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(r_gi_late_3d), statistic='mean', bins=20, range=(9,10.8))
# stat_gr_late_3d_mean, grlate_3d_means_bins, binnum_3d_grlate_mean = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(r_gr_late_3d), statistic='mean', bins=20, range=(9,10.8))

# stat_gi_late_3d_count, gilate_3d_count_bins, binnum_3d_gilate_count = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(r_gi_late_3d), statistic='count', bins=20, range=(9,10.8))
# stat_gr_late_3d_count, grlate_3d_count_bins, binnum_3d_grlate_count = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(r_gr_late_3d), statistic='count', bins=20, range=(9,10.8))

# stat_gi_std_3d_late, gilate_3d_std_bins, binnum_3d_gilate_std = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(r_gi_late_3d), statistic='std', bins=20, range=(9,10.8))
# stat_gr_std_3d_late, grlate_3d_std_bins, binnum_3d_grlate_std = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(r_gr_late_3d), statistic='std', bins=20, range=(9,10.8))



# # Average stellar mass 3D. Ratio effective radii. 20 bins early galaxies

# stat_gi_early_3d_mean, giearly_3d_means_bins, binnum_3d_giearly_mean = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(r_gi_early_3d), statistic='mean', bins=20, range=(9,11.2))
# stat_gr_early_3d_mean, grearly_3d_means_bins, binnum_3d_grearly_mean = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(r_gr_early_3d), statistic='mean', bins=20, range=(9,11.2))

# stat_gi_early_3d_count, giearly_3d_count_bins, binnum_3d_giearly_count = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(r_gi_early_3d), statistic='count', bins=20, range=(9,11.2))
# stat_gr_early_3d_count, grearly_3d_count_bins, binnum_3d_grearly_count = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(r_gr_early_3d), statistic='count', bins=20, range=(9,11.2))

# stat_gi_std_3d_early, giearly_3d_std_bins, binnum_3d_giearly_std = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(r_gi_early_3d), statistic='std', bins=20, range=(9,11.2))
# stat_gr_std_3d_early, grearly_3d_std_bins, binnum_3d_grearly_std = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(r_gr_early_3d), statistic='std', bins=20, range=(9,11.2))


# # 3D # Average stellar mass for Taylor only. No ratio, only stellar effective radius. Early and late

# stat_gilate3d_mean, gilate3d_mean_bins, binnum_gilate3d_mean = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(re_gi_late_3d), statistic='mean', bins=20, range=(9,10.8))
# stat_giearly3d_mean, giearly3d_mean_bins, binnum_giearly3d_mean = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(re_gi_early_3d), statistic='mean', bins=20, range=(9,11.2))

# stat_gilate3d_count, gilate3d_count_bins, binnum_gilate3d_count = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(re_gi_late_3d), statistic='count', bins=20, range=(9,10.8))
# stat_giearly3d_count, giearly3d_count_bins, binnum_giearly3d_count = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(re_gi_early_3d), statistic='count', bins=20, range=(9,11.2))

# stat_gilate3d_std, gilate3d_std_bins, binnum_gilate3d_std = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(re_gi_late_3d), statistic='std', bins=20, range=(9,10.8))
# stat_giearly3d_std, giearly3d_std_bins, binnum_giearly3d_std = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(re_gi_early_3d), statistic='std', bins=20, range=(9,11.2))

# # 3D # Average stellar mass for Zibetti only. No ratio, only stellar effective radius. Early and late

# stat_grlate3d_mean, grlate3d_mean_bins, brnnum_gilate3d_mean = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(re_gr_late_3d), statistic='mean', bins=20, range=(9,10.8))
# stat_grearly3d_mean, grearly3d_mean_bins, brnnum_giearly3d_mean = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(re_gr_early_3d), statistic='mean', bins=20, range=(9,11.2))

# stat_grlate3d_count, grlate3d_count_bins, brnnum_gilate3d_count = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(re_gr_late_3d), statistic='count', bins=20, range=(9,10.8))
# stat_grearly3d_count, grearly3d_count_bins, brnnum_giearly3d_count = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(re_gr_early_3d), statistic='count', bins=20, range=(9,11.2))

# stat_grlate3d_std, grlate3d_std_bins, brnnum_gilate3d_std = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(re_gr_late_3d), statistic='std', bins=20, range=(9,10.8))
# stat_grearly3d_std, grearly3d_std_bins, brnnum_giearly3d_std = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(re_gr_early_3d), statistic='std', bins=20, range=(9,11.2))

# # 3D Average density Zibetti. Stellar mass. Early and late

# stat_grS1_late3d_mean, grS1late3d_mean_bins, binnum_grS1_mean = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(S1_gr_late), statistic='mean', bins=20, range=(8,10.9))
# stat_grS1_early3d_mean, grS1early3d_mean_bins, binnum_grS1_mean = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(S1_gr_early), statistic='mean', bins=20, range=(8.7,12))

# stat_grS1_late3d_count, grS1late3d_count_bins, binnum_grS1_count = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(S1_gr_late), statistic='count', bins=20, range=(8,10.9))
# stat_grS1_early3d_count, grS1early_count_bins, binnum_grS1_count = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(S1_gr_early), statistic='count', bins=20, range=(8.7,12))

# stat_grS1_late3d_std, grS1late3d_std_bins, binnum_grS1_std = scipy.stats.binned_statistic(np.log10(Ms_gr_late_3d), np.log10(S1_gr_late), statistic='std', bins=20, range=(8,10.9))
# stat_grS1_early3d_std, grS1early3d_std_bins, binnum_grS1_std = scipy.stats.binned_statistic(np.log10(Ms_gr_early_3d), np.log10(S1_gr_early), statistic='std', bins=20, range=(8.7,12))

# # 3D Average density Taylor. Stellar mass. Early and late

# stat_giS1_late3d_mean, giS1late3d_mean_bins, binnum_giS1_mean = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(S1_gi_late), statistic='mean', bins=20, range=(8,10.9))
# stat_giS1_early3d_mean, giS1early3d_mean_bins, binnum_giS1_mean = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(S1_gi_early), statistic='mean', bins=20, range=(8.7,12))

# stat_giS1_late3d_count, giS1late3d_count_bins, binnum_giS1_count = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(S1_gi_late), statistic='count', bins=20, range=(8,10.9))
# stat_giS1_early3d_count, giS1early_count_bins, binnum_giS1_count = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(S1_gi_early), statistic='count', bins=20, range=(8.7,12))

# stat_giS1_late3d_std, giS1late3d_std_bins, binnum_giS1_std = scipy.stats.binned_statistic(np.log10(Ms_gi_late_3d), np.log10(S1_gi_late), statistic='std', bins=20, range=(8,10.9))
# stat_giS1_early3d_std, giS1early3d_std_bins, binnum_giS1_std = scipy.stats.binned_statistic(np.log10(Ms_gi_early_3d), np.log10(S1_gi_early), statistic='std', bins=20, range=(8.7,12))

# %%
# ######## 3D ###########


# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re/Rer VS Ms_gi late
# plt.hist2d(np.log10(Ms_gi_late_3d),np.log10(r_gi_late_3d), bins=(50,30), range=[[9, 12], [-1.25, 1.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(gilate_3d_means_bins[:-1], stat_gi_late_3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Late type galaxies \n Mean')
# plt.errorbar(gilate_3d_means_bins[:-1], stat_gi_late_3d_mean, yerr=stat_gi_std_3d_late, xerr=None, ls='None', ecolor='black', elinewidth=5)
# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{T11}} [M_{\odot}]$', fontsize=40)
# plt.ylabel(r'$\log (r_{3D, \Upsilon_{T11}}/r_e,r)$', fontsize=40)

# #set axis limits
# plt.ylim(-1, 1.2)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size


# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/ratio3D_Msgilate.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()


# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re/Rer VS Ms_gr late Zibetti
# plt.hist2d(np.log10(Ms_gr_late_3d),np.log10(r_gr_late_3d), bins=(50,30), range=[[9, 12], [-1.25, 1.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(grlate_3d_means_bins[:-1], stat_gr_late_3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Late type galaxies \n Mean')
# plt.errorbar(grlate_3d_means_bins[:-1], stat_gr_late_3d_mean, yerr=stat_gr_std_3d_late, xerr=None, ls='None', ecolor='black', elinewidth=5)
# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{Z09r}} [M_{\odot}]$', fontsize=40)
# plt.ylabel(r'$\log (r_{3D, \Upsilon_{Z09r}}/r_e,r)$', fontsize=40)

# #set axis limits
# plt.ylim(-1, 1.2)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size


# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/ratio3D_Msgrlate.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()


# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re/Rer VS Ms_gi early
# plt.hist2d(np.log10(Ms_gi_early_3d),np.log10(r_gi_early_3d), bins=(50,30), range=[[9, 12], [-1.25, 1.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(giearly_3d_means_bins[:-1], stat_gi_early_3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Early type galaxies \n Mean')
# plt.errorbar(giearly_3d_means_bins[:-1], stat_gi_early_3d_mean, yerr=stat_gi_std_3d_early, xerr=None, ls='None', ecolor='black', elinewidth=5)
# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{T11}} [M_{\odot}]$', fontsize=40)
# plt.ylabel(r'$\log (r_{3D, \Upsilon_{T11}}/r_e,r)$', fontsize=40)

# #set axis limits
# plt.ylim(-1, 1.2)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size


# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/ratio3D_Msgiearly.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()


# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re/Rer VS Ms_gr early Zibetti
# plt.hist2d(np.log10(Ms_gr_early_3d),np.log10(r_gr_early_3d), bins=(50,30), range=[[9, 12], [-1.25, 1.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(grearly_3d_means_bins[:-1], stat_gr_early_3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Early type galaxies \n Mean')
# plt.errorbar(grearly_3d_means_bins[:-1], stat_gr_early_3d_mean, yerr=stat_gr_std_3d_early, xerr=None, ls='None', ecolor='black', elinewidth=5)
# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{Z09r}} [M_{\odot}]$', fontsize=40)
# plt.ylabel(r'$\log (r_{3D, \Upsilon_{Z09r}}/r_e,r)$', fontsize=40)

# #set axis limits
# plt.ylim(-1, 1.2)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size


# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/ratio3D_Msgrearly.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()


# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re_gi VS Ms_gi early Taylor
# plt.hist2d(np.log10(Ms_gi_early_3d), np.log10(re_gi_early_3d), bins=(50,30), range=[[9,12],[-.35,2.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(giearly3d_mean_bins[:-1], stat_giearly3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Early type galaxies \n Mean')
# plt.errorbar(giearly3d_mean_bins[:-1], stat_giearly3d_mean, yerr=stat_giearly3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{T11}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log r_{3D, \Upsilon_{T11}}[kpc]$', fontsize=40)
# #set axis limits
# plt.ylim(-0.5, 2.5)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/reff_Msgiearly3d.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re_gi VS Ms_gr early Zibetti
# plt.hist2d(np.log10(Ms_gr_early_3d), np.log10(re_gr_early_3d), bins=(50,30), range=[[9,12],[-.35,2.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(grearly3d_mean_bins[:-1], stat_grearly3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Early type galaxies \n Mean')
# plt.errorbar(grearly3d_mean_bins[:-1], stat_grearly3d_mean, yerr=stat_grearly3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{Z09r}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log r_{3D, \Upsilon_{Z09r}}[kpc]$', fontsize=40)
# #set axis limits
# plt.ylim(-0.5, 2.5)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/reff_Msgrearly3d.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re_gi VS Ms_gi late Taylor
# plt.hist2d(np.log10(Ms_gi_late_3d), np.log10(re_gi_late_3d), bins=(50,30), range=[[9,12],[-.35,2.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(gilate3d_mean_bins[:-1], stat_gilate3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Late type galaxies \n Mean')
# plt.errorbar(gilate3d_mean_bins[:-1], stat_gilate3d_mean, yerr=stat_gilate3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{T11}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log r_{3D, \Upsilon_{T11}}[kpc]$', fontsize=40)

# #set axis limits
# plt.ylim(-0.5, 2.5)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/reff_Msgilate3d.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Re_gi VS Ms_gr late Zibetti
# plt.hist2d(np.log10(Ms_gr_late_3d), np.log10(re_gr_late_3d), bins=(50,30), range=[[9,12],[-.35,2.25]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(grlate3d_mean_bins[:-1], stat_grlate3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Late type galaxies \n Mean')
# plt.errorbar(grlate3d_mean_bins[:-1], stat_grlate3d_mean, yerr=stat_grlate3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{3D, \Upsilon_{Z09r}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log r_{3D, \Upsilon_{Z09r}}[kpc]$', fontsize=40)

# #set axis limits
# plt.ylim(-0.5, 2.5)
# plt.xlim(8.9,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/reff_Msgrlate3d.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Sigma1 VS Ms_gi late Taylor
# plt.hist2d(np.log10(Ms_gi_late_3d), np.log10(S1_gi_late), bins=(50,30), range=[[7.7,12.2],[6.5,11]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(giS1late3d_mean_bins[:-1], stat_giS1_late3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Late type galaxies \n Mean')
# plt.errorbar(giS1late3d_mean_bins[:-1], stat_giS1_late3d_mean, yerr=stat_giS1_late3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{\ast, \Upsilon_{T11}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log \rho_{1}$', fontsize=40)

# #set axis limits
# plt.ylim(6.3, 11)
# plt.xlim(7.5,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/sgm1_Msgilate3D.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Sigma1 VS Ms_gr late Zibetti
# plt.hist2d(np.log10(Ms_gr_late_3d), np.log10(S1_gr_late), bins=(50,30), range=[[7.7,12.2],[6.5,11]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(grS1late3d_mean_bins[:-1], stat_grS1_late3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Late type galaxies \n Mean')
# plt.errorbar(grS1late3d_mean_bins[:-1], stat_grS1_late3d_mean, yerr=stat_grS1_late3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{\ast, \Upsilon_{Z09r}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log \rho_{1}$', fontsize=40)

# #set axis limits
# plt.ylim(6.3, 11)
# plt.xlim(7.5,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/sgm1_Msgrlate3D.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Sigma1 VS Ms_gi early Taylor
# plt.hist2d(np.log10(Ms_gi_early_3d), np.log10(S1_gi_early), bins=(50,30), range=[[7.7,12.2],[6.5,11]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(giS1early3d_mean_bins[:-1], stat_giS1_early3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Early type galaxies \n Mean')
# plt.errorbar(giS1early3d_mean_bins[:-1], stat_giS1_early3d_mean, yerr=stat_giS1_early3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{\ast, \Upsilon_{T11}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log \rho_{1}$', fontsize=40)

# #set axis limits
# plt.ylim(6.3, 11)
# plt.xlim(7.5,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/sgm1_Msgiearly3D.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()

# fig, ax= plt.subplots(figsize=(15,12))

# # 3D Sigma1 VS Ms_gr early Zibetti
# plt.hist2d(np.log10(Ms_gr_early_3d), np.log10(S1_gr_early), bins=(50,30), range=[[7.7,12.2],[6.5,11]], zorder=1, norm=LogNorm(), cmap='viridis')
# plt.plot(grS1early3d_mean_bins[:-1], stat_grS1_early3d_mean, zorder=2, color ='black', marker = 'o', markersize= 15,  label='Early type galaxies \n Mean')
# plt.errorbar(grS1early3d_mean_bins[:-1], stat_grS1_early3d_mean, yerr=stat_grS1_early3d_std, xerr=None, ls='None', ecolor='black', elinewidth=5)

# plt.colorbar() 

# # Add axis labels

# plt.xlabel(r'$\log M_{\ast, \Upsilon_{Z09r}} [M_{\odot}]$ ', fontsize=40)
# plt.ylabel(r'$\log \rho_{1}$', fontsize=40)

# #set axis limits
# plt.ylim(6.3, 11)
# plt.xlim(7.5,12)

# #adjust tick label font size
# label_size = 25
# matplotlib.rcParams['xtick.labelsize'] = label_size 
# matplotlib.rcParams['ytick.labelsize'] = label_size

# plt.legend(fontsize=20)
# plt.savefig('/Users/ximena/Desktop/UNAM/UNAM/mass_frac/sgm1_Msgrearly3D.pdf',format='pdf',dpi=200, bbox_inches = 'tight')
# plt.show()
